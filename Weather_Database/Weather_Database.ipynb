# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(-90, 90, 2000)

lngs = np.random.uniform(-180, 180, 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations

lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = lat_lngs

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module

for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    
    if city not in cities:
        
        cities.append(city)

# Print the city count to confirm sufficient count

len(cities)
# Out:
# 719

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]
        
        city_weather_desc = str(city_weather["weather"][0]["description"])       
            
        # Append the city information into the city_data list
        
        city_data.append({
            "City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | laguna
# Processing Record 2 of Set 1 | hirara
# Processing Record 3 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 1 | san andres
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | windhoek
# Processing Record 7 of Set 1 | cidreira
# Processing Record 8 of Set 1 | talnakh
# Processing Record 9 of Set 1 | khandbari
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | boquim
# Processing Record 14 of Set 1 | puerto ayacucho
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | ostrovnoy
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | bay city
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | nome
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | guangshui
# Processing Record 25 of Set 1 | ancud
# Processing Record 26 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | faya
# Processing Record 30 of Set 1 | richards bay
# Processing Record 31 of Set 1 | asau
# Processing Record 32 of Set 1 | juneau
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | katsuura
# Processing Record 35 of Set 1 | severobaykalsk
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | filadelfia
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | san patricio
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | challapata
# Processing Record 43 of Set 1 | naron
# Processing Record 44 of Set 1 | isangel
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | nsanje
# Processing Record 48 of Set 1 | tabou
# Processing Record 49 of Set 1 | itapirapua
# Processing Record 50 of Set 1 | florence
# Processing Record 1 of Set 2 | kamenka
# Processing Record 2 of Set 2 | tasiilaq
# Processing Record 3 of Set 2 | fare
# Processing Record 4 of Set 2 | vung tau
# Processing Record 5 of Set 2 | tiksi
# Processing Record 6 of Set 2 | port lincoln
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | broken hill
# Processing Record 10 of Set 2 | tuatapere
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | shubarshi
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | erzin
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 2 | norman wells
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | achinsk
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | hammerfest
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | magnolia
# Processing Record 26 of Set 2 | salalah
# Processing Record 27 of Set 2 | cayenne
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | clyde river
# Processing Record 31 of Set 2 | sandwick
# Processing Record 32 of Set 2 | chokurdakh
# Processing Record 33 of Set 2 | poum
# Processing Record 34 of Set 2 | gornozavodsk
# Processing Record 35 of Set 2 | plouzane
# Processing Record 36 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | damphu
# Processing Record 39 of Set 2 | douentza
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | tiznit
# Processing Record 42 of Set 2 | cicuco
# Processing Record 43 of Set 2 | torbay
# Processing Record 44 of Set 2 | severo-kurilsk
# Processing Record 45 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | chocope
# Processing Record 48 of Set 2 | quepos
# Processing Record 49 of Set 2 | paramonga
# Processing Record 50 of Set 2 | boyolangu
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | nalut
# Processing Record 3 of Set 3 | xai-xai
# Processing Record 4 of Set 3 | bengkulu
# Processing Record 5 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 3 | cherskiy
# Processing Record 7 of Set 3 | margate
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | inhambane
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | lompoc
# Processing Record 12 of Set 3 | mount gambier
# Processing Record 13 of Set 3 | lavrentiya
# Processing Record 14 of Set 3 | kiama
# Processing Record 15 of Set 3 | hami
# Processing Record 16 of Set 3 | yabassi
# Processing Record 17 of Set 3 | albany
# Processing Record 18 of Set 3 | ambilobe
# Processing Record 19 of Set 3 | kaitangata
# Processing Record 20 of Set 3 | broome
# Processing Record 21 of Set 3 | kaoma
# Processing Record 22 of Set 3 | mahajanga
# Processing Record 23 of Set 3 | dalvik
# Processing Record 24 of Set 3 | narsaq
# Processing Record 25 of Set 3 | saint-philippe
# Processing Record 26 of Set 3 | carutapera
# Processing Record 27 of Set 3 | buraydah
# Processing Record 28 of Set 3 | busselton
# Processing Record 29 of Set 3 | mehran
# Processing Record 30 of Set 3 | aykhal
# Processing Record 31 of Set 3 | ardahan
# Processing Record 32 of Set 3 | srandakan
# Processing Record 33 of Set 3 | srednekolymsk
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | edd
# Processing Record 36 of Set 3 | grand gaube
# Processing Record 37 of Set 3 | kalmunai
# Processing Record 38 of Set 3 | vreed en hoop
# City not found. Skipping...
# Processing Record 39 of Set 3 | anori
# Processing Record 40 of Set 3 | cairns
# Processing Record 41 of Set 3 | esperance
# Processing Record 42 of Set 3 | mandalgovi
# Processing Record 43 of Set 3 | gamba
# Processing Record 44 of Set 3 | bowmore
# Processing Record 45 of Set 3 | boa vista
# Processing Record 46 of Set 3 | robertsport
# Processing Record 47 of Set 3 | whitianga
# Processing Record 48 of Set 3 | arani
# Processing Record 49 of Set 3 | kokopo
# Processing Record 50 of Set 3 | brigantine
# Processing Record 1 of Set 4 | kaka
# Processing Record 2 of Set 4 | coquimbo
# Processing Record 3 of Set 4 | wanaka
# Processing Record 4 of Set 4 | bethel
# Processing Record 5 of Set 4 | rudnytsya
# City not found. Skipping...
# Processing Record 6 of Set 4 | chuy
# Processing Record 7 of Set 4 | ust-nera
# Processing Record 8 of Set 4 | furstenwalde
# Processing Record 9 of Set 4 | coruripe
# Processing Record 10 of Set 4 | cape town
# Processing Record 11 of Set 4 | dicabisagan
# Processing Record 12 of Set 4 | mumford
# Processing Record 13 of Set 4 | anchorage
# Processing Record 14 of Set 4 | zhigansk
# Processing Record 15 of Set 4 | barrow
# Processing Record 16 of Set 4 | lepe
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | porto seguro
# Processing Record 19 of Set 4 | araouane
# Processing Record 20 of Set 4 | san cristobal
# Processing Record 21 of Set 4 | xinpu
# Processing Record 22 of Set 4 | rocha
# Processing Record 23 of Set 4 | qandahar
# City not found. Skipping...
# Processing Record 24 of Set 4 | shiraz
# Processing Record 25 of Set 4 | sandpoint
# Processing Record 26 of Set 4 | antonina
# Processing Record 27 of Set 4 | karpathos
# Processing Record 28 of Set 4 | teguise
# Processing Record 29 of Set 4 | saint anthony
# Processing Record 30 of Set 4 | hasaki
# Processing Record 31 of Set 4 | georgetown
# Processing Record 32 of Set 4 | limbang
# Processing Record 33 of Set 4 | sakakah
# Processing Record 34 of Set 4 | raga
# Processing Record 35 of Set 4 | port hardy
# Processing Record 36 of Set 4 | faanui
# Processing Record 37 of Set 4 | rawson
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | upernavik
# Processing Record 40 of Set 4 | portland
# Processing Record 41 of Set 4 | isabela
# Processing Record 42 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 4 | iqaluit
# Processing Record 44 of Set 4 | joshimath
# Processing Record 45 of Set 4 | toowoomba
# Processing Record 46 of Set 4 | nuuk
# Processing Record 47 of Set 4 | launceston
# Processing Record 48 of Set 4 | guerrero negro
# Processing Record 49 of Set 4 | new norfolk
# Processing Record 50 of Set 4 | berlevag
# Processing Record 1 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 5 | fallon
# Processing Record 3 of Set 5 | lubin
# Processing Record 4 of Set 5 | imperia
# Processing Record 5 of Set 5 | pacific grove
# Processing Record 6 of Set 5 | ribas do rio pardo
# Processing Record 7 of Set 5 | lasa
# Processing Record 8 of Set 5 | prince rupert
# Processing Record 9 of Set 5 | oranjemund
# Processing Record 10 of Set 5 | koulikoro
# Processing Record 11 of Set 5 | aborlan
# Processing Record 12 of Set 5 | gat
# Processing Record 13 of Set 5 | kamaishi
# Processing Record 14 of Set 5 | elko
# Processing Record 15 of Set 5 | do rud
# City not found. Skipping...
# Processing Record 16 of Set 5 | sangin
# Processing Record 17 of Set 5 | paraiso
# Processing Record 18 of Set 5 | lahij
# Processing Record 19 of Set 5 | molina
# Processing Record 20 of Set 5 | palembang
# Processing Record 21 of Set 5 | sambava
# Processing Record 22 of Set 5 | brookhaven
# Processing Record 23 of Set 5 | ocos
# Processing Record 24 of Set 5 | christchurch
# Processing Record 25 of Set 5 | kattivakkam
# Processing Record 26 of Set 5 | cockburn town
# Processing Record 27 of Set 5 | hobyo
# Processing Record 28 of Set 5 | tra vinh
# Processing Record 29 of Set 5 | te anau
# Processing Record 30 of Set 5 | eyl
# Processing Record 31 of Set 5 | vulcan
# Processing Record 32 of Set 5 | provideniya
# Processing Record 33 of Set 5 | chumphon
# Processing Record 34 of Set 5 | waipawa
# Processing Record 35 of Set 5 | sovetskiy
# Processing Record 36 of Set 5 | ouargaye
# Processing Record 37 of Set 5 | bereda
# Processing Record 38 of Set 5 | esna
# Processing Record 39 of Set 5 | manta
# Processing Record 40 of Set 5 | genhe
# Processing Record 41 of Set 5 | turukhansk
# Processing Record 42 of Set 5 | naze
# Processing Record 43 of Set 5 | san buenaventura
# Processing Record 44 of Set 5 | muisne
# Processing Record 45 of Set 5 | banda aceh
# Processing Record 46 of Set 5 | hambantota
# Processing Record 47 of Set 5 | atamanskaya
# Processing Record 48 of Set 5 | tocopilla
# Processing Record 49 of Set 5 | tautira
# Processing Record 50 of Set 5 | krems
# Processing Record 1 of Set 6 | bandarbeyla
# Processing Record 2 of Set 6 | sur
# Processing Record 3 of Set 6 | mildura
# Processing Record 4 of Set 6 | akyab
# Processing Record 5 of Set 6 | klaksvik
# Processing Record 6 of Set 6 | wasilla
# Processing Record 7 of Set 6 | monrovia
# Processing Record 8 of Set 6 | ziway
# Processing Record 9 of Set 6 | turan
# Processing Record 10 of Set 6 | bundaberg
# Processing Record 11 of Set 6 | kavaratti
# Processing Record 12 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 6 | komsomolskiy
# Processing Record 14 of Set 6 | maldonado
# Processing Record 15 of Set 6 | yenagoa
# Processing Record 16 of Set 6 | hvolsvollur
# Processing Record 17 of Set 6 | stornoway
# Processing Record 18 of Set 6 | codrington
# Processing Record 19 of Set 6 | meulaboh
# Processing Record 20 of Set 6 | ballina
# Processing Record 21 of Set 6 | lagoa
# Processing Record 22 of Set 6 | sao joao da barra
# Processing Record 23 of Set 6 | banyo
# Processing Record 24 of Set 6 | sao filipe
# Processing Record 25 of Set 6 | shache
# Processing Record 26 of Set 6 | stokmarknes
# Processing Record 27 of Set 6 | kavieng
# Processing Record 28 of Set 6 | demyanovo
# Processing Record 29 of Set 6 | saldanha
# Processing Record 30 of Set 6 | novyy urgal
# Processing Record 31 of Set 6 | jardim
# Processing Record 32 of Set 6 | sitka
# Processing Record 33 of Set 6 | champerico
# Processing Record 34 of Set 6 | corinth
# Processing Record 35 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 6 | carnarvon
# Processing Record 37 of Set 6 | polunochnoye
# Processing Record 38 of Set 6 | harper
# Processing Record 39 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 6 | koson
# Processing Record 41 of Set 6 | vardo
# Processing Record 42 of Set 6 | nizhniy tsasuchey
# Processing Record 43 of Set 6 | sawakin
# Processing Record 44 of Set 6 | comodoro rivadavia
# Processing Record 45 of Set 6 | shirokiy
# Processing Record 46 of Set 6 | lloydminster
# Processing Record 47 of Set 6 | mayo
# Processing Record 48 of Set 6 | ipixuna
# Processing Record 49 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 6 | mesetas
# Processing Record 1 of Set 7 | xadani
# City not found. Skipping...
# Processing Record 2 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 7 | montijo
# Processing Record 4 of Set 7 | deqing
# Processing Record 5 of Set 7 | gushi
# Processing Record 6 of Set 7 | karratha
# Processing Record 7 of Set 7 | vagur
# Processing Record 8 of Set 7 | kristiansund
# Processing Record 9 of Set 7 | kachiry
# Processing Record 10 of Set 7 | khatanga
# Processing Record 11 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 7 | paita
# Processing Record 13 of Set 7 | antigonish
# Processing Record 14 of Set 7 | sabang
# Processing Record 15 of Set 7 | praya
# Processing Record 16 of Set 7 | oksfjord
# Processing Record 17 of Set 7 | baykit
# Processing Record 18 of Set 7 | flinders
# Processing Record 19 of Set 7 | geraldton
# Processing Record 20 of Set 7 | leningradskiy
# Processing Record 21 of Set 7 | manaure
# Processing Record 22 of Set 7 | utete
# Processing Record 23 of Set 7 | egvekinot
# Processing Record 24 of Set 7 | half moon bay
# Processing Record 25 of Set 7 | moerai
# Processing Record 26 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 7 | assiniboia
# Processing Record 29 of Set 7 | quatre cocos
# Processing Record 30 of Set 7 | dunedin
# Processing Record 31 of Set 7 | ingleside
# Processing Record 32 of Set 7 | touros
# Processing Record 33 of Set 7 | choya
# Processing Record 34 of Set 7 | saint-augustin
# Processing Record 35 of Set 7 | lebu
# Processing Record 36 of Set 7 | vila
# Processing Record 37 of Set 7 | novoagansk
# Processing Record 38 of Set 7 | rio grande
# Processing Record 39 of Set 7 | omsukchan
# Processing Record 40 of Set 7 | alice springs
# Processing Record 41 of Set 7 | makambako
# Processing Record 42 of Set 7 | kismayo
# Processing Record 43 of Set 7 | kjollefjord
# Processing Record 44 of Set 7 | ye
# City not found. Skipping...
# Processing Record 45 of Set 7 | lorengau
# Processing Record 46 of Set 7 | mahibadhoo
# Processing Record 47 of Set 7 | walvis bay
# Processing Record 48 of Set 7 | selinia
# Processing Record 49 of Set 7 | atambua
# Processing Record 50 of Set 7 | ponta delgada
# Processing Record 1 of Set 8 | san quintin
# Processing Record 2 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 8 | winslow
# Processing Record 4 of Set 8 | mount isa
# Processing Record 5 of Set 8 | kununurra
# Processing Record 6 of Set 8 | xuchang
# Processing Record 7 of Set 8 | conceicao do araguaia
# Processing Record 8 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 8 | airai
# Processing Record 10 of Set 8 | sturgeon bay
# Processing Record 11 of Set 8 | shasta lake
# Processing Record 12 of Set 8 | plymouth
# Processing Record 13 of Set 8 | riyadh
# Processing Record 14 of Set 8 | ponta do sol
# Processing Record 15 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 16 of Set 8 | vicksburg
# Processing Record 17 of Set 8 | anadyr
# Processing Record 18 of Set 8 | salinopolis
# Processing Record 19 of Set 8 | mananjary
# Processing Record 20 of Set 8 | bathsheba
# Processing Record 21 of Set 8 | la ronge
# Processing Record 22 of Set 8 | flin flon
# Processing Record 23 of Set 8 | suluq
# Processing Record 24 of Set 8 | esfarayen
# Processing Record 25 of Set 8 | pudozh
# Processing Record 26 of Set 8 | tibiao
# Processing Record 27 of Set 8 | batticaloa
# Processing Record 28 of Set 8 | morondava
# Processing Record 29 of Set 8 | xining
# Processing Record 30 of Set 8 | husavik
# Processing Record 31 of Set 8 | smolenskaya
# Processing Record 32 of Set 8 | luena
# Processing Record 33 of Set 8 | puno
# Processing Record 34 of Set 8 | prudentopolis
# Processing Record 35 of Set 8 | merauke
# Processing Record 36 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 8 | trinidad
# Processing Record 38 of Set 8 | namatanai
# Processing Record 39 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 40 of Set 8 | qasigiannguit
# Processing Record 41 of Set 8 | padang
# Processing Record 42 of Set 8 | barentu
# Processing Record 43 of Set 8 | sri aman
# Processing Record 44 of Set 8 | altamont
# Processing Record 45 of Set 8 | jieshi
# Processing Record 46 of Set 8 | gorin
# Processing Record 47 of Set 8 | dhidhdhoo
# Processing Record 48 of Set 8 | smithers
# Processing Record 49 of Set 8 | conselheiro pena
# Processing Record 50 of Set 8 | axim
# Processing Record 1 of Set 9 | caucaia
# Processing Record 2 of Set 9 | coihaique
# Processing Record 3 of Set 9 | nazareno
# Processing Record 4 of Set 9 | busayra
# Processing Record 5 of Set 9 | winchester
# Processing Record 6 of Set 9 | biak
# Processing Record 7 of Set 9 | tual
# Processing Record 8 of Set 9 | elat
# Processing Record 9 of Set 9 | kulynychi
# Processing Record 10 of Set 9 | kruisfontein
# Processing Record 11 of Set 9 | vila velha
# Processing Record 12 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 9 | zwedru
# Processing Record 14 of Set 9 | goderich
# Processing Record 15 of Set 9 | tommot
# Processing Record 16 of Set 9 | huarmey
# Processing Record 17 of Set 9 | bilibino
# Processing Record 18 of Set 9 | sorland
# Processing Record 19 of Set 9 | mogadishu
# Processing Record 20 of Set 9 | yingcheng
# Processing Record 21 of Set 9 | saint-francois
# Processing Record 22 of Set 9 | tonj
# Processing Record 23 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 24 of Set 9 | cerkezkoy
# Processing Record 25 of Set 9 | ikalamavony
# Processing Record 26 of Set 9 | haines junction
# Processing Record 27 of Set 9 | dutse
# Processing Record 28 of Set 9 | udomlya
# Processing Record 29 of Set 9 | linjiang
# Processing Record 30 of Set 9 | bar harbor
# Processing Record 31 of Set 9 | al
# City not found. Skipping...
# Processing Record 32 of Set 9 | pryamitsyno
# Processing Record 33 of Set 9 | samarkand
# Processing Record 34 of Set 9 | bubaque
# Processing Record 35 of Set 9 | douglas
# Processing Record 36 of Set 9 | khanpur
# Processing Record 37 of Set 9 | mocuba
# Processing Record 38 of Set 9 | durango
# Processing Record 39 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 9 | churapcha
# Processing Record 41 of Set 9 | san jose
# Processing Record 42 of Set 9 | saint george
# Processing Record 43 of Set 9 | sidney
# Processing Record 44 of Set 9 | jacqueville
# Processing Record 45 of Set 9 | marsh harbour
# Processing Record 46 of Set 9 | port blair
# Processing Record 47 of Set 9 | dzialdowo
# Processing Record 48 of Set 9 | makakilo city
# Processing Record 49 of Set 9 | acarau
# Processing Record 50 of Set 9 | taltal
# Processing Record 1 of Set 10 | homer
# Processing Record 2 of Set 10 | praia da vitoria
# Processing Record 3 of Set 10 | bhadrachalam
# Processing Record 4 of Set 10 | alofi
# Processing Record 5 of Set 10 | emba
# Processing Record 6 of Set 10 | noumea
# Processing Record 7 of Set 10 | palkaka
# City not found. Skipping...
# Processing Record 8 of Set 10 | dryden
# Processing Record 9 of Set 10 | muzhi
# Processing Record 10 of Set 10 | shimoda
# Processing Record 11 of Set 10 | burias
# Processing Record 12 of Set 10 | balykshi
# Processing Record 13 of Set 10 | zhezkazgan
# Processing Record 14 of Set 10 | hauterive
# Processing Record 15 of Set 10 | tecoanapa
# Processing Record 16 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 10 | mackenzie
# Processing Record 18 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 10 | zilupe
# Processing Record 20 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 21 of Set 10 | homnabad
# Processing Record 22 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 23 of Set 10 | allapalli
# Processing Record 24 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 10 | niteroi
# Processing Record 26 of Set 10 | tazovskiy
# Processing Record 27 of Set 10 | xichang
# Processing Record 28 of Set 10 | hella
# Processing Record 29 of Set 10 | qui nhon
# Processing Record 30 of Set 10 | tubuala
# Processing Record 31 of Set 10 | strezhevoy
# Processing Record 32 of Set 10 | roebourne
# Processing Record 33 of Set 10 | kyzyl-suu
# Processing Record 34 of Set 10 | redlands
# Processing Record 35 of Set 10 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 36 of Set 10 | paamiut
# Processing Record 37 of Set 10 | surgut
# Processing Record 38 of Set 10 | lephepe
# City not found. Skipping...
# Processing Record 39 of Set 10 | samarai
# Processing Record 40 of Set 10 | shetpe
# Processing Record 41 of Set 10 | khandyga
# Processing Record 42 of Set 10 | constitucion
# Processing Record 43 of Set 10 | krasnooktyabrskiy
# Processing Record 44 of Set 10 | ossora
# Processing Record 45 of Set 10 | nanortalik
# Processing Record 46 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 10 | birjand
# Processing Record 48 of Set 10 | coos bay
# Processing Record 49 of Set 10 | vila franca do campo
# Processing Record 50 of Set 10 | togur
# Processing Record 1 of Set 11 | pisco
# Processing Record 2 of Set 11 | almenara
# Processing Record 3 of Set 11 | hopelchen
# Processing Record 4 of Set 11 | grindavik
# Processing Record 5 of Set 11 | pevek
# Processing Record 6 of Set 11 | santiago del estero
# Processing Record 7 of Set 11 | pombia
# Processing Record 8 of Set 11 | kibala
# Processing Record 9 of Set 11 | kaba
# Processing Record 10 of Set 11 | aswan
# Processing Record 11 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 11 | general roca
# Processing Record 13 of Set 11 | socastee
# Processing Record 14 of Set 11 | ixtapa
# Processing Record 15 of Set 11 | ravar
# Processing Record 16 of Set 11 | zeya
# Processing Record 17 of Set 11 | henties bay
# Processing Record 18 of Set 11 | dilla
# Processing Record 19 of Set 11 | la plata
# Processing Record 20 of Set 11 | shingu
# Processing Record 21 of Set 11 | kropotkin
# Processing Record 22 of Set 11 | monte azul
# Processing Record 23 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 11 | colares
# Processing Record 25 of Set 11 | doka
# Processing Record 26 of Set 11 | gaozhou
# Processing Record 27 of Set 11 | maceio
# Processing Record 28 of Set 11 | shelburne
# Processing Record 29 of Set 11 | sola
# Processing Record 30 of Set 11 | rohri
# Processing Record 31 of Set 11 | ceyhan
# Processing Record 32 of Set 11 | jiangyou
# Processing Record 33 of Set 11 | katobu
# Processing Record 34 of Set 11 | ajdabiya
# Processing Record 35 of Set 11 | batagay
# Processing Record 36 of Set 11 | severodvinsk
# Processing Record 37 of Set 11 | deputatskiy
# Processing Record 38 of Set 11 | cartagena
# Processing Record 39 of Set 11 | kvareli
# Processing Record 40 of Set 11 | arman
# Processing Record 41 of Set 11 | hereford
# Processing Record 42 of Set 11 | umm lajj
# Processing Record 43 of Set 11 | beba
# Processing Record 44 of Set 11 | sendhwa
# Processing Record 45 of Set 11 | bandipur
# Processing Record 46 of Set 11 | arraial do cabo
# Processing Record 47 of Set 11 | itarema
# Processing Record 48 of Set 11 | olafsvik
# Processing Record 49 of Set 11 | prescott
# Processing Record 50 of Set 11 | chapais
# Processing Record 1 of Set 12 | maltahohe
# Processing Record 2 of Set 12 | port-gentil
# Processing Record 3 of Set 12 | sao felix do xingu
# Processing Record 4 of Set 12 | fengzhen
# Processing Record 5 of Set 12 | andenes
# Processing Record 6 of Set 12 | vao
# Processing Record 7 of Set 12 | tilichiki
# Processing Record 8 of Set 12 | bambanglipuro
# Processing Record 9 of Set 12 | kargasok
# Processing Record 10 of Set 12 | irasan
# Processing Record 11 of Set 12 | moranbah
# Processing Record 12 of Set 12 | kallithea
# Processing Record 13 of Set 12 | casper
# Processing Record 14 of Set 12 | bowen
# Processing Record 15 of Set 12 | dingle
# Processing Record 16 of Set 12 | xuanhua
# Processing Record 17 of Set 12 | belmonte
# Processing Record 18 of Set 12 | sinjar
# Processing Record 19 of Set 12 | severnyy
# Processing Record 20 of Set 12 | laranjeiras do sul
# Processing Record 21 of Set 12 | dasoguz
# Processing Record 22 of Set 12 | asnaes
# Processing Record 23 of Set 12 | ponnani
# Processing Record 24 of Set 12 | luorong
# Processing Record 25 of Set 12 | kutum
# Processing Record 26 of Set 12 | purpe
# Processing Record 27 of Set 12 | mehamn
# Processing Record 28 of Set 12 | ludvika
# Processing Record 29 of Set 12 | siirt
# Processing Record 30 of Set 12 | xinzhou
# Processing Record 31 of Set 12 | kirakira
# Processing Record 32 of Set 12 | ibia
# Processing Record 33 of Set 12 | kikwit
# Processing Record 34 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 12 | sangar
# Processing Record 36 of Set 12 | port hedland
# Processing Record 37 of Set 12 | tourlaville
# Processing Record 38 of Set 12 | nizhnyaya omka
# Processing Record 39 of Set 12 | northam
# Processing Record 40 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 41 of Set 12 | kemlya
# Processing Record 42 of Set 12 | innisfail
# Processing Record 43 of Set 12 | seminole
# Processing Record 44 of Set 12 | chute-aux-outardes
# Processing Record 45 of Set 12 | koumac
# Processing Record 46 of Set 12 | lai
# Processing Record 47 of Set 12 | kaeo
# Processing Record 48 of Set 12 | kahului
# Processing Record 49 of Set 12 | dudinka
# Processing Record 50 of Set 12 | hamilton
# Processing Record 1 of Set 13 | witu
# Processing Record 2 of Set 13 | nikolayevsk-na-amure
# Processing Record 3 of Set 13 | davila
# Processing Record 4 of Set 13 | dibrugarh
# Processing Record 5 of Set 13 | namibe
# Processing Record 6 of Set 13 | manggar
# Processing Record 7 of Set 13 | guadalupe y calvo
# Processing Record 8 of Set 13 | pakdasht
# Processing Record 9 of Set 13 | balingasay
# Processing Record 10 of Set 13 | asfi
# Processing Record 11 of Set 13 | orsha
# Processing Record 12 of Set 13 | svetlaya
# Processing Record 13 of Set 13 | taoudenni
# Processing Record 14 of Set 13 | auki
# Processing Record 15 of Set 13 | aripuana
# Processing Record 16 of Set 13 | jibuti
# Processing Record 17 of Set 13 | tera
# Processing Record 18 of Set 13 | conakry
# Processing Record 19 of Set 13 | usatove
# Processing Record 20 of Set 13 | korla
# Processing Record 21 of Set 13 | kidal
# Processing Record 22 of Set 13 | hervey bay
# Processing Record 23 of Set 13 | cornwall
# Processing Record 24 of Set 13 | kendari
# Processing Record 25 of Set 13 | guane
# Processing Record 26 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 13 | yar-sale
# Processing Record 28 of Set 13 | tumaco
# Processing Record 29 of Set 13 | caravelas
# Processing Record 30 of Set 13 | ilulissat
# Processing Record 31 of Set 13 | glossa
# Processing Record 32 of Set 13 | kautokeino
# Processing Record 33 of Set 13 | hongjiang
# Processing Record 34 of Set 13 | ondarroa
# Processing Record 35 of Set 13 | gopalpur
# Processing Record 36 of Set 13 | kyrksaeterora
# Processing Record 37 of Set 13 | kozan
# Processing Record 38 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 13 | yoichi
# Processing Record 40 of Set 13 | ust-omchug
# Processing Record 41 of Set 13 | tulun
# Processing Record 42 of Set 13 | sanmenxia
# Processing Record 43 of Set 13 | mitsamiouli
# Processing Record 44 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 13 | vestmannaeyjar
# Processing Record 46 of Set 13 | carmo do rio claro
# Processing Record 47 of Set 13 | nioro
# Processing Record 48 of Set 13 | ternate
# Processing Record 49 of Set 13 | micheweni
# Processing Record 50 of Set 13 | lichinga
# Processing Record 1 of Set 14 | qarchi gak
# Processing Record 2 of Set 14 | kouroussa
# Processing Record 3 of Set 14 | hutchinson
# Processing Record 4 of Set 14 | marv dasht
# City not found. Skipping...
# Processing Record 5 of Set 14 | kolpny
# Processing Record 6 of Set 14 | jumla
# Processing Record 7 of Set 14 | pallasovka
# Processing Record 8 of Set 14 | high level
# Processing Record 9 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 14 | sisimiut
# Processing Record 11 of Set 14 | hay river
# Processing Record 12 of Set 14 | omboue
# Processing Record 13 of Set 14 | payakumbuh
# Processing Record 14 of Set 14 | ikwiriri
# Processing Record 15 of Set 14 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 16 of Set 14 | melnikovo
# Processing Record 17 of Set 14 | la rioja
# Processing Record 18 of Set 14 | chistogorskiy
# Processing Record 19 of Set 14 | karaton
# Processing Record 20 of Set 14 | aguimes
# Processing Record 21 of Set 14 | aguada de pasajeros
# Processing Record 22 of Set 14 | gornopravdinsk
# Processing Record 23 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 24 of Set 14 | alcaniz
# Processing Record 25 of Set 14 | havoysund
# Processing Record 26 of Set 14 | vryheid
# Processing Record 27 of Set 14 | bafq
# Processing Record 28 of Set 14 | magadi
# Processing Record 29 of Set 14 | boende
# Processing Record 30 of Set 14 | beloha
# Processing Record 31 of Set 14 | nelson bay
# Processing Record 32 of Set 14 | encruzilhada do sul
# Processing Record 33 of Set 14 | cam pha
# City not found. Skipping...
# Processing Record 34 of Set 14 | teknaf
# Processing Record 35 of Set 14 | xuddur
# Processing Record 36 of Set 14 | key largo
# Processing Record 37 of Set 14 | mbacke
# City not found. Skipping...
# Processing Record 38 of Set 14 | hokitika
# Processing Record 39 of Set 14 | chara
# Processing Record 40 of Set 14 | naberera
# Processing Record 41 of Set 14 | dharchula
# Processing Record 42 of Set 14 | longavi
# Processing Record 43 of Set 14 | cordoba
# Processing Record 44 of Set 14 | partizanskoye
# Processing Record 45 of Set 14 | arica
# Processing Record 46 of Set 14 | kysyl-syr
# Processing Record 47 of Set 14 | rosarito
# Processing Record 48 of Set 14 | coahuayana
# Processing Record 49 of Set 14 | burlatskoye
# Processing Record 50 of Set 14 | port shepstone
# Processing Record 1 of Set 15 | yulara
# Processing Record 2 of Set 15 | okhotsk
# Processing Record 3 of Set 15 | lerwick
# Processing Record 4 of Set 15 | verkhnevilyuysk
# Processing Record 5 of Set 15 | erenhot
# Processing Record 6 of Set 15 | bartica
# Processing Record 7 of Set 15 | cap malheureux
# Processing Record 8 of Set 15 | pozo colorado
# Processing Record 9 of Set 15 | sioux lookout
# Processing Record 10 of Set 15 | mahroni
# Processing Record 11 of Set 15 | portpatrick
# City not found. Skipping...
# Processing Record 12 of Set 15 | gravelbourg
# Processing Record 13 of Set 15 | wad madani
# Processing Record 14 of Set 15 | thunder bay
# Processing Record 15 of Set 15 | dangriga
# Processing Record 16 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 17 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 15 | matara
# Processing Record 19 of Set 15 | murmashi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have

len(city_data)
# Out:
# 662

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data

city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Laguna  38.4210 -121.4238     66.49        36           0        3.44
# 1      Hirara  24.8000  125.2833     75.47        94          20        3.44
# 2  San Andres  12.5847  -81.7006     80.62        89          75       10.36
# 3     Qaanaaq  77.4840  -69.3632    -16.98        74           3        7.72
# 4    Windhoek -22.5594   17.0832     69.42        45          32        4.61
# 5    Cidreira -30.1811  -50.2056     67.03        81          89        8.23
# 6     Talnakh  69.4865   88.3972     -2.79        95         100       22.03
# 7   Khandbari  27.3747   87.2039     52.95        74          14        3.49
# 8       Bluff -46.6000  168.3333     58.80        86         100        9.86
# 9   Jamestown  42.0970  -79.2353     31.59        78         100        9.22
#
#   Country Current Description
# 0      US           clear sky
# 1      JP          few clouds
# 2      CO       broken clouds
# 3      GL           clear sky
# 4      NA    scattered clouds
# 5      BR     overcast clouds
# 6      RU          light snow
# 7      NP          few clouds
# 8      NZ     overcast clouds
# 9      US                mist

# %%
# Display the DataFrame's column names using the columns Pandas function

city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:

# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]


# Recreate the DataFrame by using the new column order

city_data_df = city_data_df[new_column_order]

# Display sample data

city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Laguna      US  38.4210 -121.4238     66.49        36           0
# 1      Hirara      JP  24.8000  125.2833     75.47        94          20
# 2  San Andres      CO  12.5847  -81.7006     80.62        89          75
# 3     Qaanaaq      GL  77.4840  -69.3632    -16.98        74           3
# 4    Windhoek      NA -22.5594   17.0832     69.42        45          32
# 5    Cidreira      BR -30.1811  -50.2056     67.03        81          89
# 6     Talnakh      RU  69.4865   88.3972     -2.79        95         100
# 7   Khandbari      NP  27.3747   87.2039     52.95        74          14
# 8       Bluff      NZ -46.6000  168.3333     58.80        86         100
# 9   Jamestown      US  42.0970  -79.2353     31.59        78         100
#
#    Wind Speed Current Description
# 0        3.44           clear sky
# 1        3.44          few clouds
# 2       10.36       broken clouds
# 3        7.72           clear sky
# 4        4.61    scattered clouds
# 5        8.23     overcast clouds
# 6       22.03          light snow
# 7        3.49          few clouds
# 8        9.86     overcast clouds
# 9        9.22                mist

# %%
# Display the data types of each column by using the dtypes Pandas function

city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
